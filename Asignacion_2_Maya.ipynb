# %% [markdown]
# <a href="https://colab.research.google.com/github/1103050311/Template-Student-Diary/blob/main/Asignacion_2_Maya.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Muestreo

# %%
import pandas as pd
data = pd.read_csv("SoftwareProject_DataSet.csv")
data.head()

population_size =len(data)
print("El tamaño de la poblacion es", population_size)

sample_size3 = 189
print(sample_size3)

interval_K3 = (population_size//sample_size3)

systematic_sample3 = data.iloc[::interval_K3]

grouped_by_Tecnology = data.groupby('Tecnologías')
grouped_by_Tecnology.head()

group_analysis3 = grouped_by_Tecnology[['Tamaño del equipo', 'Líneas de código']].mean()
print('analisis por tecnologias')
display(group_analysis3)
# Out:
# El tamaño de la poblacion es 10000
# 189
# analisis por tecnologias
#                                   Tamaño del equipo  Líneas de código
# Tecnologías
# American, activity, scene                       7.0            5714.0
# American, against, military                     6.0            6344.0
# American, along, be                             6.0            5377.0
# American, between, these                        3.0            6274.0
# American, education, town                       5.0            5642.0
# ...                                             ...               ...
# yourself, house, why                            5.0            2180.0
# yourself, might, probably                       2.0            6110.0
# yourself, outside, entire                       1.0            2474.0
# yourself, participant, everybody                9.0            8382.0
# yourself, reduce, yeah                         10.0            4953.0
#
# [10000 rows x 2 columns]
